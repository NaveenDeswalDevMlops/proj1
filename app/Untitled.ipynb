# %%
# !pip install pydantic

# %%
pip install "pydantic[email]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [email-validator]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.getcwd()
os.chdir("/Users/naveendeswal/anaconda_projects/income/tax-badge-app")
import sqlite3

conn = sqlite3.connect("taxbadge.db")
cursor = conn.cursor()
cursor.execute("SELECT id, email, is_verified FROM users")
cursor.fetchall()
# Out:
# [(1, 'testuser@example.com', 0)]

# %%
# !pip install python-jose passlib
# Out:
# ...
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.4.8
#     Uninstalling pyasn1-0.4.8:
#       Successfully uninstalled pyasn1-0.4.8
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [python-jose] 1/4 [ecdsa]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyasn1-modules 0.2.8 requires pyasn1<0.5.0,>=0.4.6, but you have pyasn1 0.6.2 which is incompatible.
# ...
